# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn 

# %matplotlib inline

df = pd.read_csv("2018-2010_export.csv")
pd.read_csv("2018-2010_export.csv")
# Out:
#         HSCode                                          Commodity  value  \
# 0            2                        MEAT AND EDIBLE MEAT OFFAL.   0.18
# 1            3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...   0.00
# 2            4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...  12.48
# 3            6  LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...   0.00
# 4            7    EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   1.89
# 5            8  EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...  25.01
# 6            9                      COFFEE, TEA, MATE AND SPICES.  13.75
# 7           10                                           CEREALS.   0.75
# 8           11  PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCH...   0.01
# 9           12  OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEED...  10.02
# 10          13  LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND...   0.04
# 11          14  VEGETABLE PLAITING MATERIALS; VEGETABLE PRODUC...    NaN
# ...

# %%
nodupdf = df.drop_duplicates() # dropping the duplicate data
nodupdf.count() # counts of the duplicate values
# Out:
# HSCode       137023
# Commodity    137023
# value        122985
# country      137023
# year         137023
# dtype: int64

# %%
nodupdf.loc[nodupdf['country'] == 'MALAWI']
# Out:
#         HSCode                                          Commodity  value  \
# 8421         4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...   0.00
# 8422         7    EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   0.02
# 8423         8  EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...   0.01
# 8424         9                      COFFEE, TEA, MATE AND SPICES.   0.08
# 8425        10                                           CEREALS.   0.17
# 8426        11  PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCH...   0.16
# 8427        12  OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEED...   0.08
# 8428        13  LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND...   0.04
# 8429        14  VEGETABLE PLAITING MATERIALS; VEGETABLE PRODUC...    NaN
# 8430        15  ANIMAL OR VEGETABLE FATS AND OILS AND THEIR CL...   0.09
# 8431        17                    SUGARS AND SUGAR CONFECTIONERY.   0.84
# 8432        18                      COCOA AND COCOA PREPARATIONS.   0.00
# ...

# %%
df_without_missing = df.dropna()
df_without_missing
# Out:
#         HSCode                                          Commodity  value  \
# 0            2                        MEAT AND EDIBLE MEAT OFFAL.   0.18
# 1            3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...   0.00
# 2            4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...  12.48
# 3            6  LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...   0.00
# 4            7    EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   1.89
# 5            8  EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...  25.01
# 6            9                      COFFEE, TEA, MATE AND SPICES.  13.75
# 7           10                                           CEREALS.   0.75
# 8           11  PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCH...   0.01
# 9           12  OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEED...  10.02
# 10          13  LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND...   0.04
# 12          15  ANIMAL OR VEGETABLE FATS AND OILS AND THEIR CL...   0.37
# ...

# %%
df_without_missing['Export'] = 'Yes'
df_without_missing
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         HSCode                                          Commodity  value  \
# 0            2                        MEAT AND EDIBLE MEAT OFFAL.   0.18
# 1            3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...   0.00
# 2            4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...  12.48
# 3            6  LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...   0.00
# 4            7    EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   1.89
# 5            8  EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...  25.01
# ...

# %%
sns.lmplot(x='HSCode', y='value', data=df_without_missing)

# %%
df_without = df.drop(['Commodity', 'country'], axis=1)
df_without
# Out:
#         HSCode  value  year
# 0            2   0.18  2018
# 1            3   0.00  2018
# 2            4  12.48  2018
# 3            6   0.00  2018
# 4            7   1.89  2018
# 5            8  25.01  2018
# 6            9  13.75  2018
# 7           10   0.75  2018
# 8           11   0.01  2018
# 9           12  10.02  2018
# 10          13   0.04  2018
# 11          14    NaN  2018
# 12          15   0.37  2018
# 13          17  15.92  2018
# 14          18   0.00  2018
# 15          19   0.63  2018
# 16          20   5.04  2018
# 17          21   3.08  2018
# 18          22   0.01  2018
# 19          23   0.22  2018
# 20          24  91.22  2018
# 21          25   0.02  2018
# 22          27   0.59  2018
# 23          28   1.08  2018
# 24          29   7.15  2018
# 25          30  80.27  2018
# 26          31   0.00  2018
# 27          32   0.21  2018
# 28          33   5.63  2018
# 29          34   0.32  2018
# ...        ...    ...   ...
# 136993      63   6.64  2010
# ...

# %%
sns.boxplot(data = df_without_missing)

# %%
df_without.dropna()
# Out:
#         HSCode  value  year
# 0            2   0.18  2018
# 1            3   0.00  2018
# 2            4  12.48  2018
# 3            6   0.00  2018
# 4            7   1.89  2018
# 5            8  25.01  2018
# 6            9  13.75  2018
# 7           10   0.75  2018
# 8           11   0.01  2018
# 9           12  10.02  2018
# 10          13   0.04  2018
# 12          15   0.37  2018
# 13          17  15.92  2018
# 14          18   0.00  2018
# 15          19   0.63  2018
# 16          20   5.04  2018
# 17          21   3.08  2018
# 18          22   0.01  2018
# 19          23   0.22  2018
# 20          24  91.22  2018
# 21          25   0.02  2018
# 22          27   0.59  2018
# 23          28   1.08  2018
# 24          29   7.15  2018
# 25          30  80.27  2018
# 26          31   0.00  2018
# 27          32   0.21  2018
# 28          33   5.63  2018
# 29          34   0.32  2018
# 30          35   0.04  2018
# ...        ...    ...   ...
# 136991      61   0.13  2010
# ...

# %%
df_without
# Out:
# HSCode    137023
# value     122985
# year      137023
# dtype: int64

# %%
df_without['value'] = df_without['value'].fillna(df_without['value'].mean())

# %%
df_without.isnull().sum()
# Out:
# HSCode    0
# value     0
# year      0
# dtype: int64

# %%
corr = df_without_missing.corr()
sns.heatmap(corr, vmin=-1, annot=True)

# %%
sns.countplot(x='HSCode',
              data=df_without_missing)

# %%
import statsmodels.formula.api as smf
result = smf.ols('HSCode ~ country + value + year', data=df_without_missing).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 HSCode   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     4.380
# Date:                Wed, 21 Aug 2019   Prob (F-statistic):          5.48e-105
# Time:                        16:14:07   Log-Likelihood:            -5.8296e+05
# No. Observations:              122985   AIC:                         1.166e+06
# Df Residuals:                  122735   BIC:                         1.169e+06
# Df Model:                         249
# Covariance Type:            nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# ...

# %%
import sklearn 
from sklearn.linear_model import LinearRegression
X = df_without.drop('year', axis = 1)
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(
    X, df_without.year, test_size=0.30, random_state = 5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (95916, 2)
# (41107, 2)
# (95916,)
# (41107,)

# %%
lm = LinearRegression()
lm.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-3b43fa9c58a2> in <module>
#       1 lm = LinearRegression()
# ----> 2 lm.fit(X_train, Y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...
