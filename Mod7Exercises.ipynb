# %% [markdown]
# # Module 7 Exercises - Linear Regression

# %% [markdown]
# ### Exercise 1:
#
# Using the pandas library, in the datasets folder load the gradedata.csv file as a dataframe. Narrow your data (make the dataframe smaller) by choosing columns that you think can help predict student grades. Use any method that you've learned so far to help your decision on which columns to keep.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn 

# %matplotlib inline

Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)

# %%
df_without = df.drop(['fname','lname', 'address', 'gender'], axis=1)
sns.boxplot(data = df_without)

# %% [markdown]
# ### Exercise 2:
#
# Using the dataframe in the exercise above, clean and prepare your data. This means to eliminate any null (missing) values (either by dropping or filling them) and to transform any data column types to numerical values that a model can interpret. For example, if the column has string values, convert them to integers that best represent their order.

# %%
df_without_missing = df_without.dropna()
df_without_missing
# Out:
#       age  exercise  hours  grade
# 0      17         3     10   82.4
# 1      18         4      4   78.2
# 2      18         5      9   79.3
# 3      14         2      7   83.2
# 4      18         4     15   87.4
# 5      16         5     16   88.7
# 6      17         1      9   80.2
# 7      17         5     18   95.1
# 8      15         5      9   76.5
# 9      15         3     15   89.7
# 10     16         2     13   85.2
# 11     15         2     10   75.3
# 12     14         4     12   80.7
# 13     15         2     15   84.2
# 14     18         1     14   87.6
# 15     15         1      8   75.8
# 16     16         1     10   88.2
# 17     19         1     19  100.0
# 18     18         4     13   84.3
# 19     19         4     11   84.2
# 20     18         3     11   79.1
# 21     15         1     15   90.5
# 22     16         2      9   71.0
# 23     14         5     18   90.3
# 24     17         5      6   82.4
# 25     14         1     10   83.8
# 26     15         5     18   94.5
# 27     18         1     16   83.5
# 28     16         1      9   69.7
# 29     16         2     13   91.1
# ...   ...       ...    ...    ...
# 1970   19         2     14   93.2
# 1971   17         3     16   90.4
# 1972   17         5     13   79.5
# 1973   14         3     10   74.2
# 1974   16         1      8   68.0
# 1975   15         4     11   75.2
# 1976   16         2      8   74.5
# 1977   14         3     18   85.6
# 1978   17         2     12   82.7
# 1979   17         5     17  100.0
# 1980   17         4     19   91.9
# 1981   15         5     15  100.0
# 1982   18         1      6   61.4
# 1983   14         1     14   93.1
# 1984   15         1      4   72.7
# 1985   15         4      6   74.4
# 1986   19         2     14   91.3
# 1987   15         5     11   78.6
# 1988   15         1     14   78.0
# 1989   14         2     14   91.2
# 1990   17         2      8   70.2
# 1991   16         3      7   64.9
# 1992   14         5      9   78.5
# 1993   14         2     10   74.3
# 1994   17         5      5   67.5
# 1995   19         1      8   80.1
# 1996   16         4     18  100.0
# 1997   18         3     14   84.9
# 1998   16         1      7   69.1
# 1999   19         4     10   79.6
#
# [2000 rows x 4 columns]

# %% [markdown]
# ### Exercise 3:
#
# Using the cleaned dataframe in the exercise above, use the sklearn library to split the data into training and test datasets. Make the test size 30%.

# %%
import sklearn 
from sklearn.linear_model import LinearRegression
X = df_without_missing.drop('exercise', axis = 1)
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(
    X, df_without_missing.exercise, test_size=0.30, random_state = 5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (1400, 3)
# (600, 3)
# (1400,)
# (600,)

# %% [markdown]
# ### Exercise 4:
#
# Using the training data from the previous exercise, set a linear regression function to fit the data (build the model).

# %%
lm = LinearRegression()
lm.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# ### Exercise 5:
#
# What is the intercept coefficient (y-intercept) for the linear regression model?

# %%
print('Estimated intercept coefficient:', lm.intercept_)
# Out:
# Estimated intercept coefficient: -0.7385376163410622

# %% [markdown]
# ### Exercise 6:
#
# Use the predict function on the training data and the test data.

# %%
pred_train = lm.predict(X_train)
pred_test = lm.predict(X_test)

# %% [markdown]
# ### Exercise 7:
#
# Calculate the score of the training and test predictions. How "good" was the linear regression model at predicting the test data compared to the training data?

# %%
print(lm.score(X_train, Y_train))
print(lm.score(X_test, Y_test))
#The two predictions comparing the training and the test data were similar.
# Out:
# 0.05872276076348226
# 0.053457024656905376
