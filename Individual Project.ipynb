# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

location = "heart.csv"
df = pd.read_csv(location)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
#printing the means for various attributes that are considered to be attributed to cardiovascular disease
print(df['age'].mean())
print(df['cp'].mean())
print(df['chol'].mean())
print(df['thalach'].mean())
print(df['oldpeak'].mean())
# Out:
# 54.366336633663366
# 0.966996699669967
# 246.26402640264027
# 149.64686468646866
# 1.0396039603960396

# %%
#printing the modes for each attribute
print(df['age'].mode())
print(df['cp'].mode())
print(df['chol'].mode())
print(df['thalach'].mode())
print(df['oldpeak'].mode())
# Out:
# 0    58
# dtype: int64
# 0    0
# dtype: int64
# 0    197
# 1    204
# 2    234
# dtype: int64
# 0    162
# dtype: int64
# 0    0.0
# dtype: float64

# %%
#bar chart of age
sns.countplot(x='age', data=df)

# %%
#bar chart for range of chest pain
sns.countplot(x='cp', data=df)

# %%
sns.barplot('sex', 'cp', data=df)

# %%
sns.barplot('target', 'cp', data=df)

# %%
sns.barplot('target', 'age', data=df)

# %%
sns.barplot('target', 'chol', data=df)

# %%
sns.barplot('trestbps', 'cp', data=df)

# %%
#density plot in order to look at various variables
plt.figure(figsize=(10,6))

ax = sns.kdeplot(df['age'][df['cp'] == 1], 
                 color="darkturquoise",
                 shade=True)

sns.kdeplot(df['age'][df['target'] == 0], 
            color="lightcoral",
            shade=True)

plt.legend (['Chest Pain', 'Target'])
plt.title("Density Plot of Age for Chest Pain vs Presence of Disease")

ax.set(xlabel='Age')
#plt.show()
# Out:
# [Text(0.5, 0, 'Age')]

# %%
#get the number of missing values in each column
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#grouping by sex, chest pain, and if the patient has heart disease, by the average age.
#This shows the gender, and what was the severity of their chest pain, and if they had heart disease. 
df.groupby(['sex', 'cp', 'target'])['age'].mean()
# Out:
# sex  cp  target
# 0    0   0         59.047619
#          1         55.166667
#      1   0         57.500000
#          1         51.250000
#      2   0         62.000000
#          1         54.764706
#      3   1         63.250000
# 1    0   0         55.602410
#          1         53.142857
#      1   0         57.428571
#          1         49.240000
#      2   0         58.294118
#          1         49.742857
#      3   0         55.142857
#          1         53.833333
# Name: age, dtype: float64

# %%
#grouping by major indicators of cardiovascular disease
df.groupby(['age', 'cp', 'chol'])['age'].mean()
# Out:
# age  cp  chol
# 29   1   204     29
# 34   1   210     34
#      3   182     34
# 35   0   183     35
#          198     35
#          282     35
#      1   192     35
# 37   2   215     37
#          250     37
# 38   2   175     38
#      3   231     38
# 39   0   219     39
#      2   199     39
#          220     39
#          321     39
# 40   0   167     40
#          223     40
#      3   199     40
# 41   0   172     41
#      1   157     41
#          198     41
#          203     41
#          204     41
#          235     41
#          306     41
#      2   214     41
#          250     41
#          268     41
# 42   0   226     42
#          265     42
#                  ..
# 66   0   302     66
#      1   246     66
#      2   278     66
#      3   226     66
# 67   0   223     67
#          229     67
#          237     67
#          254     67
#          286     67
#          299     67
#      2   212     67
#          277     67
#          564     67
# ...

# %%
modeldf = df.drop(['fbs','restecg','exang', 'slope', 'ca', 'thal', 'oldpeak'], axis=1)
modeldf.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'thalach', 'target'], dtype='object')

# %%
modeldf
# Out:
#      age  sex  cp  trestbps  chol  thalach  target
# 0     63    1   3       145   233      150       1
# 1     37    1   2       130   250      187       1
# 2     41    0   1       130   204      172       1
# 3     56    1   1       120   236      178       1
# 4     57    0   0       120   354      163       1
# 5     57    1   0       140   192      148       1
# 6     56    0   1       140   294      153       1
# 7     44    1   1       120   263      173       1
# 8     52    1   2       172   199      162       1
# 9     57    1   2       150   168      174       1
# 10    54    1   0       140   239      160       1
# 11    48    0   2       130   275      139       1
# 12    49    1   1       130   266      171       1
# 13    64    1   3       110   211      144       1
# 14    58    0   3       150   283      162       1
# 15    50    0   2       120   219      158       1
# 16    58    0   2       120   340      172       1
# ...

# %%
modeldf.rename(columns={'age': 'Age'}, inplace =True)
modeldf.rename(columns={'sex': 'Sex'}, inplace =True)
modeldf.rename(columns={'cp': 'Chest Pain'}, inplace =True)
modeldf.rename(columns={'Resting Blood Pressure': 'Resting BP'}, inplace =True)
modeldf.rename(columns={'chol': 'Cholesterol'}, inplace =True)
modeldf.rename(columns={'thalach': 'Maximum HR'}, inplace =True)
modeldf.rename(columns={'Presence of Heart Disease': 'Heart Disease?'}, inplace =True)
modeldf
# Out:
#      Age  Sex  Chest Pain  Resting BP  Cholesterol  Maximum HR  Heart Disease?
# 0     63    1           3         145          233         150               1
# 1     37    1           2         130          250         187               1
# 2     41    0           1         130          204         172               1
# 3     56    1           1         120          236         178               1
# 4     57    0           0         120          354         163               1
# 5     57    1           0         140          192         148               1
# 6     56    0           1         140          294         153               1
# 7     44    1           1         120          263         173               1
# 8     52    1           2         172          199         162               1
# 9     57    1           2         150          168         174               1
# 10    54    1           0         140          239         160               1
# ...

# %%
meanage = modeldf['Age'].mean()
stdage = modeldf['Age'].std()
toprange = meanage + stdage * 1.96
botrange = meanage - stdage * 1.96

finaldf = modeldf.copy() #to not mess up the original df
finaldf = finaldf.drop(finaldf[finaldf['Age'] > toprange].index)
finaldf = finaldf.drop(finaldf[finaldf['Age'] < botrange].index)

finaldf
# Out:
#      Age  Sex  Chest Pain  Resting BP  Cholesterol  Maximum HR  Heart Disease?
# 0     63    1           3         145          233         150               1
# 1     37    1           2         130          250         187               1
# 2     41    0           1         130          204         172               1
# 3     56    1           1         120          236         178               1
# 4     57    0           0         120          354         163               1
# 5     57    1           0         140          192         148               1
# 6     56    0           1         140          294         153               1
# 7     44    1           1         120          263         173               1
# 8     52    1           2         172          199         162               1
# 9     57    1           2         150          168         174               1
# 10    54    1           0         140          239         160               1
# ...

# %%
finaldf.describe()
# Out:
#               Age         Sex  Chest Pain  Resting BP  Cholesterol  \
# count  293.000000  293.000000  293.000000  293.000000   293.000000
# mean    54.638225    0.686007    0.969283  131.825939   247.088737
# std      8.389012    0.464908    1.034877   17.745936    51.916678
# min     37.000000    0.000000    0.000000   94.000000   126.000000
# 25%     48.000000    0.000000    0.000000  120.000000   212.000000
# 50%     56.000000    1.000000    1.000000  130.000000   242.000000
# 75%     61.000000    1.000000    2.000000  140.000000   275.000000
# max     71.000000    1.000000    3.000000  200.000000   564.000000
#
#        Maximum HR  Heart Disease?
# count  293.000000      293.000000
# mean   149.262799        0.539249
# std     22.596882        0.499310
# min     71.000000        0.000000
# 25%    134.000000        0.000000
# 50%    152.000000        1.000000
# 75%    165.000000        1.000000
# max    195.000000        1.000000

# %%
finaldf.to_csv('HeartDisease.csv',index = False)
